# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = [12,6]
plt.style.use("ggplot")

# %% [markdown]
# # Data Set 1 Avacado

# %%
data = pd.read_csv(r"C:\Users\jaskeerat singh\Desktop\technocolabs internship\mini task 1\avocado.csv")

# %% [markdown]
# # Exploratory Data Analytics

# %%
data = data.drop("Unnamed: 0", axis = 1)
data
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
data.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
data.tail()
# Out:
#              Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244  2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# ...

# %%
data.shape
# Out:
# (18249, 13)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=18249, step=1)

# %%
data.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
data.nunique()
# Out:
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# # Data Visualisations

# %%
data["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
region_df = data.groupby("region")["AveragePrice"].mean().to_frame().sort_values(by = "AveragePrice", ascending = False).head(10)
sns.barplot(region_df.index, region_df["AveragePrice"], data = region_df)
plt.title("Top 10 regions with best Average")
plt.xlabel("Regions")
plt.ylabel("Average Price")
plt.xticks(rotation = "vertical")
plt.show()

# %%
region = data.groupby("region")["AveragePrice"].mean().to_frame()
plt.plot(region.index, region["AveragePrice"], label = "Plot line", marker = "o", lw = 4, ls = "-.", color = "#32a852", markeredgecolor = "#000000")
plt.xlabel("All the Regions")
plt.ylabel("Average Values")
plt.title("Average values of all the regions")
plt.xticks(rotation = "vertical")
plt.legend()
plt.show()

# %%
data["year"].unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
sns.barplot(data["year"],data["AveragePrice"], hue = data["type"])
plt.xlabel("Years")
plt.ylabel("Average Price")
plt.legend()
plt.show()

# %%
albany_df = data[data['region']=="Albany"]
albany_df.set_index("Date", inplace=True)
albany_df["AveragePrice"].plot()
plt.xlabel("Dates")
plt.ylabel("Average Price")
plt.title("Plot for Average Prices of Albany")
plt.show()

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()
plt.xlabel("Dates")
plt.ylabel("Average Price")
plt.title("Plot for Average Prices of Albany using rolling value")
plt.show()

# %% [markdown]
# # Data Set 2 Minimum Wage

# %%
minwage = pd.read_csv(r"C:\Users\jaskeerat singh\Desktop\technocolabs internship\mini task 1\Minimum Wage Data.csv", encoding="latin")

# %%
minwage
# Out:
#       Year          State           Table_Data Footnote  High.Value  \
# 0     1968        Alabama                  ...      NaN     0.00000
# 1     1968         Alaska                 2.10      NaN     2.10000
# 2     1968        Arizona  18.72 - 26.40/wk(b)      (b)     0.66000
# 3     1968       Arkansas          1.25/day(b)      (b)     0.15625
# 4     1968     California              1.65(b)      (b)     1.65000
# ...    ...            ...                  ...      ...         ...
# 2745  2017       Virginia              7.25[c]      [c]     7.25000
# 2746  2017     Washington                11.00      NaN    11.00000
# 2747  2017  West Virginia                 8.75      NaN     8.75000
# 2748  2017      Wisconsin                 7.25      NaN     7.25000
# 2749  2017        Wyoming                 5.15      NaN     5.15000
#
#       Low.Value  CPI.Average  High.2018  Low.2018
# 0       0.00000    34.783333       0.00      0.00
# ...

# %% [markdown]
# # Exploratory Data analysis

# %%
minwage.head()
# Out:
#    Year       State           Table_Data Footnote  High.Value  Low.Value  \
# 0  1968     Alabama                  ...      NaN     0.00000    0.00000
# 1  1968      Alaska                 2.10      NaN     2.10000    2.10000
# 2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000    0.46800
# 3  1968    Arkansas          1.25/day(b)      (b)     0.15625    0.15625
# 4  1968  California              1.65(b)      (b)     1.65000    1.65000
#
#    CPI.Average  High.2018  Low.2018
# 0    34.783333       0.00      0.00
# 1    34.783333      15.12     15.12
# 2    34.783333       4.75      3.37
# 3    34.783333       1.12      1.12
# 4    34.783333      11.88     11.88

# %%
minwage.tail()
# Out:
#       Year          State Table_Data Footnote  High.Value  Low.Value  \
# 2745  2017       Virginia    7.25[c]      [c]        7.25       7.25
# 2746  2017     Washington      11.00      NaN       11.00      11.00
# 2747  2017  West Virginia       8.75      NaN        8.75       8.75
# 2748  2017      Wisconsin       7.25      NaN        7.25       7.25
# 2749  2017        Wyoming       5.15      NaN        5.15       5.15
#
#       CPI.Average  High.2018  Low.2018
# 2745   245.119583       7.41      7.41
# 2746   245.119583      11.24     11.24
# 2747   245.119583       8.94      8.94
# 2748   245.119583       7.41      7.41
# 2749   245.119583       5.26      5.26

# %%
minwage.index
# Out:
# RangeIndex(start=0, stop=2750, step=1)

# %%
minwage.shape
# Out:
# (2750, 9)

# %%
minwage.columns
# Out:
# Index(['Year', 'State', 'Table_Data', 'Footnote', 'High.Value', 'Low.Value',
#        'CPI.Average', 'High.2018', 'Low.2018'],
#       dtype='object')

# %%
minwage.dtypes
# Out:
# Year             int64
# State           object
# Table_Data      object
# Footnote        object
# High.Value     float64
# Low.Value      float64
# CPI.Average    float64
# High.2018      float64
# Low.2018       float64
# dtype: object

# %%
minwage.nunique()
# Out:
# Year            50
# State           55
# Table_Data     310
# Footnote        11
# High.Value     170
# Low.Value      176
# CPI.Average     50
# High.2018      489
# Low.2018       540
# dtype: int64

# %%
minwage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2750 entries, 0 to 2749
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         2750 non-null   int64
#  1   State        2750 non-null   object
#  2   Table_Data   2739 non-null   object
#  3   Footnote     418 non-null    object
#  4   High.Value   2739 non-null   float64
#  5   Low.Value    2739 non-null   float64
#  6   CPI.Average  2750 non-null   float64
#  7   High.2018    2739 non-null   float64
#  8   Low.2018     2739 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 193.5+ KB

# %%
minwage.describe()
# Out:
#               Year   High.Value    Low.Value  CPI.Average    High.2018  \
# count  2750.000000  2739.000000  2739.000000  2750.000000  2739.000000
# mean   1992.500000     3.653761     3.533555   138.828983     6.441486
# std      14.433494     2.560308     2.539424    65.823807     3.025140
# min    1968.000000     0.000000     0.000000    34.783333     0.000000
# 25%    1980.000000     1.600000     1.600000    82.408333     5.980000
# 50%    1992.500000     3.350000     3.350000   142.387500     7.370000
# 75%    2005.000000     5.150000     5.150000   195.291667     8.280000
# max    2017.000000    11.500000    11.500000   245.119583    15.120000
#
#           Low.2018
# count  2739.000000
# mean      6.200252
# std       3.017818
# min       0.000000
# 25%       5.230000
# 50%       7.170000
# 75%       8.070000
# max      15.120000

# %% [markdown]
# # Data visualisation

# %%
act_min_wage = pd.DataFrame()

for name, group in minwage.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Low.2018"]].rename(columns={"Low.2018":name}))

act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.12     3.37      1.12       11.88      7.20        10.08
# 1969      0.0   14.33     3.19      1.07       11.26      6.83         9.56
# 1970      0.0   13.54     3.02      7.09       10.64      6.45        10.32
# 1971      0.0   12.99     2.89      6.80       10.20      6.18         9.89
# 1972      0.0   12.57     2.80      7.19        9.88      5.99        11.08
#
#       Delaware  District of Columbia  Federal (FLSA)  ...  Tennessee  Texas  \
# Year                                                  ...
# 1968      9.00                  9.00            8.28  ...        0.0   0.00
# 1969      8.53                  8.53            7.85  ...        0.0   0.00
# 1970      8.06                 10.32            8.38  ...        0.0   0.00
# 1971      7.73                  9.89            8.04  ...        0.0   0.00
# ...

# %%
act_min_wage.corr()
# Out:
#                       Alabama    Alaska   Arizona  Arkansas  California  \
# Alabama                   NaN       NaN       NaN       NaN         NaN
# Alaska                    NaN  1.000000  0.018638 -0.377934    0.717653
# Arizona                   NaN  0.018638  1.000000  0.089395    0.498994
# Arkansas                  NaN -0.377934  0.089395  1.000000   -0.234367
# California                NaN  0.717653  0.498994 -0.234367    1.000000
# Colorado                  NaN -0.129332  0.742527  0.135749    0.483313
# Connecticut               NaN  0.680886  0.458163  0.047580    0.876215
# Delaware                  NaN  0.258997  0.429836  0.016125    0.479197
# District of Columbia      NaN  0.321785  0.590848  0.266889    0.596865
# Federal (FLSA)            NaN  0.637679 -0.049914  0.117245    0.371966
# Florida                   NaN -0.227059  0.896702  0.226320    0.304550
# Georgia                   NaN -0.569150  0.088429  0.473108   -0.389749
# ...

# %%
issue_df = minwage[minwage['Low.2018']==0]
issue_df.head()
# Out:
#     Year     State Table_Data Footnote  High.Value  Low.Value  CPI.Average  \
# 0   1968   Alabama        ...      NaN         0.0        0.0    34.783333
# 10  1968   Florida        ...      NaN         0.0        0.0    34.783333
# 11  1968   Georgia        ...      NaN         0.0        0.0    34.783333
# 15  1968  Illinois        ...      NaN         0.0        0.0    34.783333
# 17  1968      Iowa        ...      NaN         0.0        0.0    34.783333
#
#     High.2018  Low.2018
# 0         0.0       0.0
# 10        0.0       0.0
# 11        0.0       0.0
# 15        0.0       0.0
# 17        0.0       0.0

# %%
wagecorr = act_min_wage.replace(0, np.NaN).dropna(axis=1).corr()

# %%
plt.matshow(wagecorr)
plt.show()

# %%
# pip install lxml html5lib bs4
# on mac, run: /Applications/Python\ 3.7/Install\ Certificates.command


import requests

web = requests.get("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")
dfs = pd.read_html(web.text)


import pandas as pd

# https://www.infoplease.com/state-abbreviations-and-state-postal-codes

dfs = pd.read_html("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")

# %%
for df in dfs:
    print(df.head())
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA
#   Territory/Associate Abbreviation Postal Code
# 0      American Samoa            Â          AS
# 1                Guam         Guam          GU
# 2    Marshall Islands            Â          MH
# 3          Micronesia            Â          FM
# 4   Northern Marianas            Â          MP

# %%
state_abbv = dfs[0]

state_abbv.head()
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA
